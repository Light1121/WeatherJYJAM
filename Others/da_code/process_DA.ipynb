# %% [markdown]
# ### V1 process data - merge into one file.

# %%
import os
import glob
import pandas as pd
from pandas.errors import EmptyDataError

# Paths
RAW_BASE    = r"E:\study\meteoroData_raw"
CLEANED_DIR = r"E:\study\meteoroData_clean"
os.makedirs(CLEANED_DIR, exist_ok=True)

# List of states to process
states = ["vic", "nsw", "qld"]

# Container for all DataFrames
all_dfs = []

# Full list of 11 column names from the raw CSV
colnames_11 = [
    "station",            # 0: station identifier
    "date",               # 1: date (DD/MM/YYYY)
    "evap_0000_2400",     # 2: evaporation 0000–2400
    "rainfall_0900_0900", # 3: rainfall 0900–0900
    "evap_0900_0900",     # 4: evaporation 0900–0900
    "max_temp",           # 5: maximum temperature (°C)
    "min_temp",           # 6: minimum temperature (°C)
    "max_humid",          # 7: maximum relative humidity (%)
    "min_humid",          # 8: minimum relative humidity (%)
    "wind_speed",         # 9: wind speed (m/s)
    "solar"               # 10: solar exposure (MJ/m²)
]

for state in states:
    folder = os.path.join(RAW_BASE, state)
    pattern = os.path.join(folder, "*.csv")

    for fpath in glob.glob(pattern):
        # Skip zero-byte files
        if os.path.getsize(fpath) == 0:
            print(f"[Skip] Empty file: {fpath}")
            continue

        # Read CSV, skipping the first 13 lines of header/notes
        try:
            df = pd.read_csv(fpath, skiprows=13, header=None, encoding="utf-8")
        except EmptyDataError:
            print(f"[Skip] No data: {fpath}")
            continue

        # Validate column count and assign names
        ncol = df.shape[1]
        if ncol == 11:
            df.columns = colnames_11
        elif ncol == 10:
            # Some files may lack the 'solar' column
            df.columns = colnames_11[:-1]
        else:
            print(f"[Skip] Unexpected column count ({ncol}): {fpath}")
            continue

        # Convert date to ISO format YYYY-MM-DD
        df["date"] = pd.to_datetime(df["date"], dayfirst=True).dt.strftime("%Y-%m-%d")
        # Add a state column
        df["state"] = state.upper()

        # Keep only the 8 required columns and rename them
        df = df[[
            "date", "state", "station",
            "max_temp", "min_temp",
            "max_humid", "min_humid",
            "wind_speed"
        ]]
        df.rename(columns={
            "max_temp":  "max_Temperature_C",
            "min_temp":  "min_Temperature_C",
            "max_humid": "max_Humidity_pct",
            "min_humid": "min_Humidity_pct",
            "wind_speed":"wind_speed_m_s"
        }, inplace=True)

        all_dfs.append(df)
        print(f"✔ Processed: {os.path.basename(fpath)}")

# Merge and write out
if all_dfs:
    big_df = pd.concat(all_dfs, ignore_index=True)
    out_f = os.path.join(CLEANED_DIR, "all_states_weather.csv")
    big_df.to_csv(out_f, index=False, encoding="utf-8")
    print(f"\n✅ Done! {len(big_df)} records written to: {out_f}")
else:
    print("⚠️ No valid data processed. Please check the raw files.")
# Out:
# ✔ Processed: avalon_airport-202211.csv
# ✔ Processed: avalon_airport-202212.csv
# ✔ Processed: bairnsdale_airport-202205.csv
# ✔ Processed: ballarat_aerodrome-202205.csv
# ✔ Processed: cape_nelson_lighthouse-202205.csv
# ✔ Processed: cape_otway_lighthouse-202205.csv
# ✔ Processed: casterton-202205.csv
# ✔ Processed: cerberus-202205.csv
# ✔ Processed: charlton-202205.csv
# ✔ Processed: coldstream-202205.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202205.csv
# ✔ Processed: combienbar-202205.csv
# ✔ Processed: dartmoor-202205.csv
# ✔ Processed: dartmoor-202206.csv
# ✔ Processed: avalon_airport-202301.csv
# ✔ Processed: avalon_airport-202302.csv
# ✔ Processed: avalon_airport-202303.csv
# ✔ Processed: avalon_airport-202304.csv
# ✔ Processed: avalon_airport-202305.csv
# ✔ Processed: avalon_airport-202306.csv
# ✔ Processed: avalon_airport-202307.csv
# ✔ Processed: avalon_airport-202308.csv
# ✔ Processed: avalon_airport-202309.csv
# ✔ Processed: avalon_airport-202310.csv
# ✔ Processed: avalon_airport-202311.csv
# ✔ Processed: avalon_airport-202312.csv
# ✔ Processed: avalon_airport-202401.csv
# ✔ Processed: avalon_airport-202402.csv
# ✔ Processed: avalon_airport-202403.csv
# ✔ Processed: avalon_airport-202404.csv
# ✔ Processed: avalon_airport-202405.csv
# ✔ Processed: avalon_airport-202406.csv
# ✔ Processed: avalon_airport-202407.csv
# ✔ Processed: avalon_airport-202408.csv
# ✔ Processed: avalon_airport-202409.csv
# ✔ Processed: avalon_airport-202410.csv
# ✔ Processed: avalon_airport-202411.csv
# ✔ Processed: avalon_airport-202412.csv
# ✔ Processed: avalon_airport-202501.csv
# ✔ Processed: avalon_airport-202502.csv
# ✔ Processed: avalon_airport-202503.csv
# ✔ Processed: avalon_airport-202504.csv
# ✔ Processed: bairnsdale_airport-202206.csv
# ✔ Processed: bairnsdale_airport-202207.csv
# ✔ Processed: bairnsdale_airport-202208.csv
# ✔ Processed: bairnsdale_airport-202209.csv
# ✔ Processed: bairnsdale_airport-202210.csv
# ✔ Processed: bairnsdale_airport-202211.csv
# ✔ Processed: bairnsdale_airport-202212.csv
# ✔ Processed: bairnsdale_airport-202301.csv
# ✔ Processed: bairnsdale_airport-202302.csv
# ✔ Processed: bairnsdale_airport-202303.csv
# ✔ Processed: bairnsdale_airport-202304.csv
# ✔ Processed: bairnsdale_airport-202305.csv
# ✔ Processed: bairnsdale_airport-202306.csv
# ✔ Processed: bairnsdale_airport-202307.csv
# ✔ Processed: bairnsdale_airport-202308.csv
# ✔ Processed: bairnsdale_airport-202309.csv
# ✔ Processed: bairnsdale_airport-202310.csv
# ✔ Processed: bairnsdale_airport-202311.csv
# ✔ Processed: bairnsdale_airport-202312.csv
# ✔ Processed: bairnsdale_airport-202401.csv
# ✔ Processed: bairnsdale_airport-202402.csv
# ✔ Processed: bairnsdale_airport-202403.csv
# ✔ Processed: bairnsdale_airport-202404.csv
# ✔ Processed: bairnsdale_airport-202405.csv
# ✔ Processed: bairnsdale_airport-202406.csv
# ✔ Processed: bairnsdale_airport-202407.csv
# ✔ Processed: bairnsdale_airport-202408.csv
# ✔ Processed: bairnsdale_airport-202409.csv
# ✔ Processed: bairnsdale_airport-202410.csv
# ✔ Processed: bairnsdale_airport-202411.csv
# ✔ Processed: bairnsdale_airport-202412.csv
# ✔ Processed: bairnsdale_airport-202501.csv
# ✔ Processed: bairnsdale_airport-202502.csv
# ✔ Processed: bairnsdale_airport-202503.csv
# ✔ Processed: bairnsdale_airport-202504.csv
# ✔ Processed: ballarat_aerodrome-202206.csv
# ✔ Processed: ballarat_aerodrome-202207.csv
# ✔ Processed: ballarat_aerodrome-202208.csv
# ✔ Processed: ballarat_aerodrome-202209.csv
# ✔ Processed: ballarat_aerodrome-202211.csv
# ✔ Processed: ballarat_aerodrome-202212.csv
# ✔ Processed: ballarat_aerodrome-202301.csv
# ✔ Processed: ballarat_aerodrome-202302.csv
# ✔ Processed: ballarat_aerodrome-202303.csv
# ✔ Processed: ballarat_aerodrome-202304.csv
# ✔ Processed: ballarat_aerodrome-202305.csv
# ✔ Processed: ballarat_aerodrome-202306.csv
# ✔ Processed: ballarat_aerodrome-202307.csv
# ✔ Processed: ballarat_aerodrome-202308.csv
# ✔ Processed: ballarat_aerodrome-202309.csv
# ✔ Processed: ballarat_aerodrome-202310.csv
# ✔ Processed: ballarat_aerodrome-202311.csv
# ✔ Processed: ballarat_aerodrome-202312.csv
# ✔ Processed: ballarat_aerodrome-202401.csv
# ✔ Processed: ballarat_aerodrome-202402.csv
# ✔ Processed: ballarat_aerodrome-202403.csv
# ✔ Processed: ballarat_aerodrome-202404.csv
# ✔ Processed: ballarat_aerodrome-202405.csv
# ✔ Processed: ballarat_aerodrome-202406.csv
# ✔ Processed: ballarat_aerodrome-202407.csv
# ✔ Processed: ballarat_aerodrome-202408.csv
# ✔ Processed: ballarat_aerodrome-202409.csv
# ✔ Processed: ballarat_aerodrome-202410.csv
# ✔ Processed: ballarat_aerodrome-202411.csv
# ✔ Processed: ballarat_aerodrome-202412.csv
# ✔ Processed: ballarat_aerodrome-202501.csv
# ✔ Processed: ballarat_aerodrome-202502.csv
# ✔ Processed: ballarat_aerodrome-202503.csv
# ✔ Processed: ballarat_aerodrome-202504.csv
# ✔ Processed: bendigo_airport-202205.csv
# ✔ Processed: bendigo_airport-202206.csv
# ✔ Processed: bendigo_airport-202207.csv
# ✔ Processed: bendigo_airport-202208.csv
# ✔ Processed: bendigo_airport-202209.csv
# ✔ Processed: bendigo_airport-202210.csv
# ✔ Processed: bendigo_airport-202211.csv
# ✔ Processed: bendigo_airport-202212.csv
# ✔ Processed: bendigo_airport-202301.csv
# ✔ Processed: bendigo_airport-202302.csv
# ✔ Processed: bendigo_airport-202303.csv
# ✔ Processed: bendigo_airport-202304.csv
# ✔ Processed: bendigo_airport-202305.csv
# ✔ Processed: bendigo_airport-202306.csv
# ✔ Processed: bendigo_airport-202307.csv
# ✔ Processed: bendigo_airport-202308.csv
# ✔ Processed: bendigo_airport-202309.csv
# ✔ Processed: bendigo_airport-202310.csv
# ✔ Processed: bendigo_airport-202311.csv
# ✔ Processed: bendigo_airport-202312.csv
# ✔ Processed: bendigo_airport-202401.csv
# ✔ Processed: bendigo_airport-202402.csv
# ✔ Processed: bendigo_airport-202403.csv
# ✔ Processed: bendigo_airport-202404.csv
# ✔ Processed: bendigo_airport-202405.csv
# ✔ Processed: bendigo_airport-202406.csv
# ✔ Processed: bendigo_airport-202407.csv
# ✔ Processed: bendigo_airport-202408.csv
# ✔ Processed: bendigo_airport-202409.csv
# ✔ Processed: bendigo_airport-202410.csv
# ✔ Processed: bendigo_airport-202411.csv
# ✔ Processed: bendigo_airport-202412.csv
# ✔ Processed: bendigo_airport-202501.csv
# ✔ Processed: bendigo_airport-202502.csv
# ✔ Processed: bendigo_airport-202503.csv
# ✔ Processed: bendigo_airport-202504.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202205.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202206.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202207.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202208.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202209.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202210.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202211.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202212.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202301.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202302.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202303.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202304.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202305.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202306.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202307.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202308.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202309.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202310.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202311.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202312.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202401.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202402.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202403.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202404.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202405.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202406.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202407.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202408.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202409.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202410.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202411.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202412.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202501.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202502.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202503.csv
# ✔ Processed: breakwater_(geelong_racecourse)-202504.csv
# ✔ Processed: cape_nelson_lighthouse-202206.csv
# ✔ Processed: cape_nelson_lighthouse-202207.csv
# ✔ Processed: cape_nelson_lighthouse-202208.csv
# ✔ Processed: cape_nelson_lighthouse-202209.csv
# ✔ Processed: cape_nelson_lighthouse-202210.csv
# ✔ Processed: cape_nelson_lighthouse-202211.csv
# ✔ Processed: cape_nelson_lighthouse-202212.csv
# ✔ Processed: cape_nelson_lighthouse-202301.csv
# ✔ Processed: cape_nelson_lighthouse-202302.csv
# ✔ Processed: cape_nelson_lighthouse-202303.csv
# ✔ Processed: cape_nelson_lighthouse-202304.csv
# ✔ Processed: cape_nelson_lighthouse-202305.csv
# ✔ Processed: cape_nelson_lighthouse-202306.csv
# ✔ Processed: cape_nelson_lighthouse-202307.csv
# ✔ Processed: cape_nelson_lighthouse-202308.csv
# ✔ Processed: cape_nelson_lighthouse-202309.csv
# ✔ Processed: cape_nelson_lighthouse-202310.csv
# ✔ Processed: cape_nelson_lighthouse-202311.csv
# ✔ Processed: cape_nelson_lighthouse-202312.csv
# ✔ Processed: cape_nelson_lighthouse-202401.csv
# ✔ Processed: cape_nelson_lighthouse-202402.csv
# ✔ Processed: cape_nelson_lighthouse-202403.csv
# ✔ Processed: cape_nelson_lighthouse-202404.csv
# ✔ Processed: cape_nelson_lighthouse-202405.csv
# ✔ Processed: cape_nelson_lighthouse-202406.csv
# ✔ Processed: cape_nelson_lighthouse-202407.csv
# ✔ Processed: cape_nelson_lighthouse-202408.csv
# ✔ Processed: cape_nelson_lighthouse-202409.csv
# ✔ Processed: cape_nelson_lighthouse-202410.csv
# ✔ Processed: cape_nelson_lighthouse-202411.csv
# ✔ Processed: cape_nelson_lighthouse-202412.csv
# ✔ Processed: cape_nelson_lighthouse-202501.csv
# ✔ Processed: cape_nelson_lighthouse-202502.csv
# ✔ Processed: cape_nelson_lighthouse-202503.csv
# ✔ Processed: cape_nelson_lighthouse-202504.csv
# ✔ Processed: cape_otway_lighthouse-202206.csv
# ✔ Processed: cape_otway_lighthouse-202207.csv
# ✔ Processed: cape_otway_lighthouse-202208.csv
# ✔ Processed: cape_otway_lighthouse-202209.csv
# ✔ Processed: cape_otway_lighthouse-202210.csv
# ✔ Processed: cape_otway_lighthouse-202211.csv
# ✔ Processed: cape_otway_lighthouse-202212.csv
# ✔ Processed: cape_otway_lighthouse-202301.csv
# ✔ Processed: cape_otway_lighthouse-202302.csv
# ✔ Processed: cape_otway_lighthouse-202303.csv
# ✔ Processed: cape_otway_lighthouse-202304.csv
# ✔ Processed: cape_otway_lighthouse-202305.csv
# ✔ Processed: cape_otway_lighthouse-202306.csv
# ✔ Processed: cape_otway_lighthouse-202307.csv
# ✔ Processed: cape_otway_lighthouse-202308.csv
# ✔ Processed: cape_otway_lighthouse-202309.csv
# ✔ Processed: cape_otway_lighthouse-202310.csv
# ✔ Processed: cape_otway_lighthouse-202311.csv
# ✔ Processed: cape_otway_lighthouse-202312.csv
# ✔ Processed: cape_otway_lighthouse-202401.csv
# ✔ Processed: cape_otway_lighthouse-202402.csv
# ✔ Processed: cape_otway_lighthouse-202403.csv
# ✔ Processed: cape_otway_lighthouse-202404.csv
# ✔ Processed: cape_otway_lighthouse-202405.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202205.csv
# ✔ Processed: cape_otway_lighthouse-202406.csv
# ✔ Processed: cape_otway_lighthouse-202407.csv
# ✔ Processed: cape_otway_lighthouse-202408.csv
# ✔ Processed: cape_otway_lighthouse-202409.csv
# ✔ Processed: cape_otway_lighthouse-202410.csv
# ✔ Processed: cape_otway_lighthouse-202411.csv
# ✔ Processed: cape_otway_lighthouse-202412.csv
# ✔ Processed: cape_otway_lighthouse-202501.csv
# ✔ Processed: cape_otway_lighthouse-202502.csv
# ✔ Processed: cape_otway_lighthouse-202503.csv
# ✔ Processed: cape_otway_lighthouse-202504.csv
# ✔ Processed: casterton-202206.csv
# ✔ Processed: casterton-202207.csv
# ✔ Processed: casterton-202208.csv
# ✔ Processed: casterton-202209.csv
# ✔ Processed: casterton-202210.csv
# ✔ Processed: casterton-202211.csv
# ✔ Processed: casterton-202212.csv
# ✔ Processed: casterton-202301.csv
# ✔ Processed: casterton-202302.csv
# ✔ Processed: casterton-202303.csv
# ✔ Processed: casterton-202304.csv
# ✔ Processed: casterton-202305.csv
# ✔ Processed: casterton-202306.csv
# ✔ Processed: casterton-202307.csv
# ✔ Processed: casterton-202308.csv
# ✔ Processed: casterton-202309.csv
# ✔ Processed: casterton-202310.csv
# ✔ Processed: casterton-202311.csv
# ✔ Processed: casterton-202312.csv
# ✔ Processed: casterton-202401.csv
# ✔ Processed: casterton-202402.csv
# ✔ Processed: casterton-202403.csv
# ✔ Processed: casterton-202404.csv
# ✔ Processed: essendon_airport-202407.csv
# ✔ Processed: casterton-202405.csv
# ✔ Processed: casterton-202406.csv
# ✔ Processed: casterton-202407.csv
# ✔ Processed: casterton-202408.csv
# ✔ Processed: casterton-202409.csv
# ✔ Processed: casterton-202410.csv
# ✔ Processed: casterton-202411.csv
# ✔ Processed: casterton-202412.csv
# ✔ Processed: casterton-202501.csv
# ✔ Processed: casterton-202502.csv
# ✔ Processed: casterton-202503.csv
# ✔ Processed: casterton-202504.csv
# ✔ Processed: cerberus-202206.csv
# ✔ Processed: cerberus-202207.csv
# ✔ Processed: cerberus-202208.csv
# ✔ Processed: cerberus-202209.csv
# ✔ Processed: cerberus-202210.csv
# ✔ Processed: cerberus-202211.csv
# ✔ Processed: cerberus-202212.csv
# ✔ Processed: cerberus-202301.csv
# ✔ Processed: cerberus-202302.csv
# ✔ Processed: cerberus-202303.csv
# ✔ Processed: cerberus-202304.csv
# ✔ Processed: cerberus-202305.csv
# ✔ Processed: cerberus-202306.csv
# ✔ Processed: cerberus-202307.csv
# ✔ Processed: cerberus-202308.csv
# ✔ Processed: cerberus-202309.csv
# ✔ Processed: cerberus-202310.csv
# ✔ Processed: cerberus-202311.csv
# ✔ Processed: cerberus-202312.csv
# ✔ Processed: cerberus-202401.csv
# ✔ Processed: cerberus-202402.csv
# ✔ Processed: cerberus-202403.csv
# ✔ Processed: cerberus-202404.csv
# ✔ Processed: cerberus-202405.csv
# ✔ Processed: cerberus-202406.csv
# ✔ Processed: cerberus-202407.csv
# ✔ Processed: cerberus-202408.csv
# ✔ Processed: cerberus-202409.csv
# ✔ Processed: cerberus-202410.csv
# ✔ Processed: cerberus-202411.csv
# ✔ Processed: cerberus-202412.csv
# ✔ Processed: cerberus-202501.csv
# ✔ Processed: cerberus-202502.csv
# ✔ Processed: cerberus-202503.csv
# ✔ Processed: cerberus-202504.csv
# ✔ Processed: charlton-202206.csv
# ✔ Processed: charlton-202207.csv
# ✔ Processed: charlton-202208.csv
# ✔ Processed: charlton-202209.csv
# ✔ Processed: charlton-202210.csv
# ✔ Processed: charlton-202211.csv
# ✔ Processed: charlton-202212.csv
# ✔ Processed: charlton-202301.csv
# ✔ Processed: charlton-202302.csv
# ✔ Processed: charlton-202303.csv
# ✔ Processed: charlton-202304.csv
# ✔ Processed: charlton-202305.csv
# ✔ Processed: charlton-202306.csv
# ✔ Processed: charlton-202307.csv
# ✔ Processed: charlton-202308.csv
# ✔ Processed: charlton-202309.csv
# ✔ Processed: charlton-202310.csv
# ✔ Processed: charlton-202311.csv
# ✔ Processed: charlton-202312.csv
# ✔ Processed: charlton-202401.csv
# ✔ Processed: charlton-202402.csv
# ✔ Processed: charlton-202403.csv
# ✔ Processed: charlton-202404.csv
# ✔ Processed: charlton-202405.csv
# ✔ Processed: charlton-202406.csv
# ✔ Processed: charlton-202407.csv
# ✔ Processed: charlton-202408.csv
# ✔ Processed: charlton-202409.csv
# ✔ Processed: charlton-202410.csv
# ✔ Processed: charlton-202411.csv
# ✔ Processed: charlton-202412.csv
# ✔ Processed: charlton-202501.csv
# ✔ Processed: charlton-202502.csv
# ✔ Processed: charlton-202503.csv
# ✔ Processed: charlton-202504.csv
# ✔ Processed: colac_(mount_gellibrand)-202205.csv
# ✔ Processed: colac_(mount_gellibrand)-202206.csv
# ✔ Processed: colac_(mount_gellibrand)-202207.csv
# ✔ Processed: colac_(mount_gellibrand)-202208.csv
# ✔ Processed: colac_(mount_gellibrand)-202209.csv
# ✔ Processed: colac_(mount_gellibrand)-202210.csv
# ✔ Processed: colac_(mount_gellibrand)-202211.csv
# ✔ Processed: colac_(mount_gellibrand)-202212.csv
# ✔ Processed: colac_(mount_gellibrand)-202301.csv
# ✔ Processed: colac_(mount_gellibrand)-202302.csv
# ✔ Processed: colac_(mount_gellibrand)-202303.csv
# ✔ Processed: colac_(mount_gellibrand)-202304.csv
# ✔ Processed: colac_(mount_gellibrand)-202305.csv
# ✔ Processed: colac_(mount_gellibrand)-202306.csv
# ✔ Processed: colac_(mount_gellibrand)-202307.csv
# ✔ Processed: colac_(mount_gellibrand)-202308.csv
# ✔ Processed: colac_(mount_gellibrand)-202309.csv
# ✔ Processed: essendon_airport-202408.csv
# ✔ Processed: essendon_airport-202409.csv
# ✔ Processed: colac_(mount_gellibrand)-202310.csv
# ✔ Processed: colac_(mount_gellibrand)-202311.csv
# ✔ Processed: colac_(mount_gellibrand)-202312.csv
# ✔ Processed: colac_(mount_gellibrand)-202401.csv
# ✔ Processed: colac_(mount_gellibrand)-202402.csv
# ✔ Processed: colac_(mount_gellibrand)-202403.csv
# ✔ Processed: colac_(mount_gellibrand)-202404.csv
# ✔ Processed: colac_(mount_gellibrand)-202405.csv
# ✔ Processed: colac_(mount_gellibrand)-202406.csv
# ✔ Processed: colac_(mount_gellibrand)-202407.csv
# ✔ Processed: colac_(mount_gellibrand)-202408.csv
# ✔ Processed: colac_(mount_gellibrand)-202409.csv
# ✔ Processed: colac_(mount_gellibrand)-202410.csv
# ✔ Processed: colac_(mount_gellibrand)-202411.csv
# ✔ Processed: colac_(mount_gellibrand)-202412.csv
# ✔ Processed: colac_(mount_gellibrand)-202501.csv
# ✔ Processed: colac_(mount_gellibrand)-202502.csv
# ✔ Processed: colac_(mount_gellibrand)-202503.csv
# ✔ Processed: colac_(mount_gellibrand)-202504.csv
# ✔ Processed: coldstream-202206.csv
# ✔ Processed: coldstream-202207.csv
# ✔ Processed: coldstream-202208.csv
# ✔ Processed: coldstream-202209.csv
# ✔ Processed: coldstream-202210.csv
# ✔ Processed: coldstream-202211.csv
# ✔ Processed: coldstream-202212.csv
# ✔ Processed: coldstream-202301.csv
# ✔ Processed: coldstream-202302.csv
# ✔ Processed: coldstream-202303.csv
# ✔ Processed: coldstream-202304.csv
# ✔ Processed: coldstream-202305.csv
# ✔ Processed: coldstream-202306.csv
# ✔ Processed: coldstream-202307.csv
# ✔ Processed: coldstream-202308.csv
# ✔ Processed: coldstream-202309.csv
# ✔ Processed: coldstream-202310.csv
# ✔ Processed: coldstream-202311.csv
# ✔ Processed: coldstream-202312.csv
# ✔ Processed: coldstream-202401.csv
# ✔ Processed: coldstream-202402.csv
# ✔ Processed: coldstream-202403.csv
# ✔ Processed: coldstream-202404.csv
# ✔ Processed: coldstream-202405.csv
# ✔ Processed: coldstream-202406.csv
# ✔ Processed: coldstream-202407.csv
# ✔ Processed: coldstream-202408.csv
# ✔ Processed: coldstream-202409.csv
# ✔ Processed: coldstream-202410.csv
# ✔ Processed: coldstream-202411.csv
# ✔ Processed: coldstream-202412.csv
# ✔ Processed: coldstream-202501.csv
# ✔ Processed: coldstream-202502.csv
# ✔ Processed: coldstream-202503.csv
# ✔ Processed: coldstream-202504.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202206.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202207.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202208.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202209.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202210.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202211.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202212.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202301.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202302.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202303.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202304.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202305.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202306.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202307.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202308.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202309.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202310.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202311.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202312.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202401.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202402.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202403.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202404.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202405.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202406.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202407.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202408.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202409.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202410.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202411.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202412.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202501.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202502.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202503.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\coldstream_comparison-202504.csv
# ✔ Processed: combienbar-202206.csv
# ✔ Processed: combienbar-202207.csv
# ✔ Processed: combienbar-202208.csv
# ✔ Processed: combienbar-202209.csv
# ✔ Processed: combienbar-202210.csv
# ✔ Processed: combienbar-202211.csv
# ✔ Processed: combienbar-202212.csv
# ✔ Processed: combienbar-202301.csv
# ✔ Processed: combienbar-202302.csv
# ✔ Processed: combienbar-202303.csv
# ✔ Processed: combienbar-202304.csv
# ✔ Processed: combienbar-202305.csv
# ✔ Processed: combienbar-202306.csv
# ✔ Processed: combienbar-202307.csv
# ✔ Processed: combienbar-202308.csv
# ✔ Processed: combienbar-202309.csv
# ✔ Processed: combienbar-202310.csv
# ✔ Processed: combienbar-202311.csv
# ✔ Processed: combienbar-202312.csv
# ✔ Processed: combienbar-202401.csv
# ✔ Processed: combienbar-202402.csv
# ✔ Processed: combienbar-202403.csv
# ✔ Processed: combienbar-202404.csv
# ✔ Processed: combienbar-202405.csv
# ✔ Processed: combienbar-202406.csv
# ✔ Processed: combienbar-202407.csv
# ✔ Processed: combienbar-202408.csv
# ✔ Processed: combienbar-202409.csv
# ✔ Processed: combienbar-202410.csv
# ✔ Processed: combienbar-202411.csv
# ✔ Processed: combienbar-202412.csv
# ✔ Processed: combienbar-202501.csv
# ✔ Processed: combienbar-202502.csv
# ✔ Processed: combienbar-202503.csv
# ✔ Processed: combienbar-202504.csv
# ✔ Processed: corner_inlet_(yanakie)-202205.csv
# ✔ Processed: corner_inlet_(yanakie)-202206.csv
# ✔ Processed: corner_inlet_(yanakie)-202207.csv
# ✔ Processed: corner_inlet_(yanakie)-202208.csv
# ✔ Processed: corner_inlet_(yanakie)-202209.csv
# ✔ Processed: corner_inlet_(yanakie)-202210.csv
# ✔ Processed: corner_inlet_(yanakie)-202211.csv
# ✔ Processed: corner_inlet_(yanakie)-202212.csv
# ✔ Processed: corner_inlet_(yanakie)-202301.csv
# ✔ Processed: corner_inlet_(yanakie)-202302.csv
# ✔ Processed: corner_inlet_(yanakie)-202303.csv
# ✔ Processed: corner_inlet_(yanakie)-202304.csv
# ✔ Processed: corner_inlet_(yanakie)-202305.csv
# ✔ Processed: corner_inlet_(yanakie)-202306.csv
# ✔ Processed: corner_inlet_(yanakie)-202307.csv
# ✔ Processed: corner_inlet_(yanakie)-202308.csv
# ✔ Processed: corner_inlet_(yanakie)-202309.csv
# ✔ Processed: corner_inlet_(yanakie)-202310.csv
# ✔ Processed: corner_inlet_(yanakie)-202311.csv
# ✔ Processed: corner_inlet_(yanakie)-202312.csv
# ✔ Processed: corner_inlet_(yanakie)-202401.csv
# ✔ Processed: corner_inlet_(yanakie)-202402.csv
# ✔ Processed: corner_inlet_(yanakie)-202403.csv
# ✔ Processed: corner_inlet_(yanakie)-202404.csv
# ✔ Processed: corner_inlet_(yanakie)-202405.csv
# ✔ Processed: corner_inlet_(yanakie)-202406.csv
# ✔ Processed: corner_inlet_(yanakie)-202407.csv
# ✔ Processed: corner_inlet_(yanakie)-202408.csv
# ✔ Processed: corner_inlet_(yanakie)-202409.csv
# ✔ Processed: corner_inlet_(yanakie)-202410.csv
# ✔ Processed: corner_inlet_(yanakie)-202411.csv
# ✔ Processed: corner_inlet_(yanakie)-202412.csv
# ✔ Processed: corner_inlet_(yanakie)-202501.csv
# ✔ Processed: corner_inlet_(yanakie)-202502.csv
# ✔ Processed: corner_inlet_(yanakie)-202503.csv
# ✔ Processed: corner_inlet_(yanakie)-202504.csv
# ✔ Processed: dartmoor-202207.csv
# ✔ Processed: dartmoor-202208.csv
# ✔ Processed: dartmoor-202209.csv
# ✔ Processed: dartmoor-202210.csv
# ✔ Processed: dartmoor-202211.csv
# ✔ Processed: dartmoor-202212.csv
# ✔ Processed: dartmoor-202301.csv
# ✔ Processed: dartmoor-202302.csv
# ✔ Processed: dartmoor-202303.csv
# ✔ Processed: dartmoor-202304.csv
# ✔ Processed: dartmoor-202305.csv
# ✔ Processed: dartmoor-202306.csv
# ✔ Processed: dartmoor-202307.csv
# ✔ Processed: dartmoor-202308.csv
# ✔ Processed: dartmoor-202309.csv
# ✔ Processed: dartmoor-202310.csv
# ✔ Processed: dartmoor-202311.csv
# ✔ Processed: dartmoor-202312.csv
# ✔ Processed: dartmoor-202401.csv
# ✔ Processed: dartmoor-202402.csv
# ✔ Processed: dartmoor-202403.csv
# ✔ Processed: dartmoor-202404.csv
# ✔ Processed: dartmoor-202405.csv
# ✔ Processed: dartmoor-202406.csv
# ✔ Processed: dartmoor-202407.csv
# ✔ Processed: dartmoor-202408.csv
# ✔ Processed: dartmoor-202409.csv
# ✔ Processed: dartmoor-202410.csv
# ✔ Processed: dartmoor-202411.csv
# ✔ Processed: dartmoor-202412.csv
# ✔ Processed: dartmoor-202501.csv
# ✔ Processed: dartmoor-202502.csv
# ✔ Processed: dartmoor-202503.csv
# ✔ Processed: dartmoor-202504.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202206.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202207.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202208.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202209.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202210.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202211.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202212.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202301.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202302.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202303.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202304.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202305.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202306.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202307.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202308.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202309.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202310.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202311.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202312.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202401.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202402.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202403.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202404.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202405.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202406.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202407.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202408.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202409.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202410.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202411.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202412.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202501.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202502.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202503.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\deniliquin_airport-202504.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202205.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202206.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202207.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202208.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202209.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202210.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202211.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202212.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202301.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202302.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202303.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202304.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202305.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202306.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202307.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202308.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202309.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202310.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202311.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202312.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202401.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202402.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202403.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202404.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202405.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202406.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202407.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202408.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202409.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202410.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202411.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202412.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202501.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202502.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202503.csv
# ✔ Processed: dinner_plain_(mount_hotham_airport)-202504.csv
# ✔ Processed: essendon_airport-202410.csv
# ✔ Processed: essendon_airport-202411.csv
# ✔ Processed: essendon_airport-202412.csv
# ✔ Processed: essendon_airport-202501.csv
# ✔ Processed: essendon_airport-202502.csv
# ✔ Processed: essendon_airport-202503.csv
# ✔ Processed: essendon_airport-202504.csv
# ✔ Processed: essendon_airport-202205.csv
# ✔ Processed: essendon_airport-202206.csv
# ✔ Processed: essendon_airport-202207.csv
# ✔ Processed: essendon_airport-202208.csv
# ✔ Processed: essendon_airport-202209.csv
# ✔ Processed: essendon_airport-202210.csv
# ✔ Processed: essendon_airport-202211.csv
# ✔ Processed: essendon_airport-202212.csv
# ✔ Processed: essendon_airport-202301.csv
# ✔ Processed: essendon_airport-202302.csv
# ✔ Processed: essendon_airport-202303.csv
# ✔ Processed: essendon_airport-202304.csv
# ✔ Processed: essendon_airport-202305.csv
# ✔ Processed: essendon_airport-202306.csv
# ✔ Processed: essendon_airport-202307.csv
# ✔ Processed: essendon_airport-202308.csv
# ✔ Processed: essendon_airport-202309.csv
# ✔ Processed: essendon_airport-202310.csv
# ✔ Processed: essendon_airport-202311.csv
# ✔ Processed: essendon_airport-202312.csv
# ✔ Processed: essendon_airport-202401.csv
# ✔ Processed: essendon_airport-202402.csv
# ✔ Processed: essendon_airport-202403.csv
# ✔ Processed: essendon_airport-202404.csv
# ✔ Processed: essendon_airport-202405.csv
# ✔ Processed: essendon_airport-202406.csv
# ✔ Processed: falls_creek-202205.csv
# ✔ Processed: falls_creek-202206.csv
# ✔ Processed: falls_creek-202207.csv
# ✔ Processed: falls_creek-202208.csv
# ✔ Processed: falls_creek-202209.csv
# ✔ Processed: falls_creek-202210.csv
# ✔ Processed: falls_creek-202211.csv
# ✔ Processed: falls_creek-202212.csv
# ✔ Processed: falls_creek-202301.csv
# ✔ Processed: falls_creek-202302.csv
# ✔ Processed: falls_creek-202303.csv
# ✔ Processed: falls_creek-202304.csv
# ✔ Processed: falls_creek-202305.csv
# ✔ Processed: falls_creek-202306.csv
# ✔ Processed: falls_creek-202307.csv
# ✔ Processed: falls_creek-202308.csv
# ✔ Processed: falls_creek-202309.csv
# ✔ Processed: falls_creek-202310.csv
# ✔ Processed: falls_creek-202311.csv
# ✔ Processed: falls_creek-202312.csv
# ✔ Processed: falls_creek-202401.csv
# ✔ Processed: falls_creek-202402.csv
# ✔ Processed: falls_creek-202403.csv
# ✔ Processed: falls_creek-202404.csv
# ✔ Processed: falls_creek-202405.csv
# ✔ Processed: falls_creek-202406.csv
# ✔ Processed: falls_creek-202407.csv
# ✔ Processed: falls_creek-202408.csv
# ✔ Processed: falls_creek-202409.csv
# ✔ Processed: falls_creek-202410.csv
# ✔ Processed: falls_creek-202411.csv
# ✔ Processed: falls_creek-202412.csv
# ✔ Processed: falls_creek-202501.csv
# ✔ Processed: falls_creek-202502.csv
# ✔ Processed: falls_creek-202503.csv
# ✔ Processed: falls_creek-202504.csv
# ✔ Processed: ferny_creek-202205.csv
# ✔ Processed: ferny_creek-202206.csv
# ✔ Processed: ferny_creek-202207.csv
# ✔ Processed: ferny_creek-202208.csv
# ✔ Processed: ferny_creek-202209.csv
# ✔ Processed: ferny_creek-202210.csv
# ✔ Processed: ferny_creek-202211.csv
# ✔ Processed: ferny_creek-202212.csv
# ✔ Processed: ferny_creek-202301.csv
# ✔ Processed: ferny_creek-202302.csv
# ✔ Processed: ferny_creek-202303.csv
# ✔ Processed: ferny_creek-202304.csv
# ✔ Processed: ferny_creek-202305.csv
# ✔ Processed: ferny_creek-202306.csv
# ✔ Processed: ferny_creek-202307.csv
# ✔ Processed: ferny_creek-202308.csv
# ✔ Processed: ferny_creek-202309.csv
# ✔ Processed: ferny_creek-202310.csv
# ✔ Processed: ferny_creek-202311.csv
# ✔ Processed: ferny_creek-202312.csv
# ✔ Processed: ferny_creek-202401.csv
# ✔ Processed: ferny_creek-202402.csv
# ✔ Processed: ferny_creek-202403.csv
# ✔ Processed: ferny_creek-202404.csv
# ✔ Processed: ferny_creek-202405.csv
# ✔ Processed: ferny_creek-202406.csv
# ✔ Processed: ferny_creek-202407.csv
# ✔ Processed: ferny_creek-202408.csv
# ✔ Processed: ferny_creek-202409.csv
# ✔ Processed: ferny_creek-202410.csv
# ✔ Processed: ferny_creek-202411.csv
# ✔ Processed: ferny_creek-202412.csv
# ✔ Processed: ferny_creek-202501.csv
# ✔ Processed: ferny_creek-202502.csv
# ✔ Processed: ferny_creek-202503.csv
# ✔ Processed: ferny_creek-202504.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202205.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202206.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202207.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202208.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202209.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202210.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202211.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202212.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202301.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202302.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202303.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202304.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202305.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202306.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202307.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202308.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202309.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202310.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202311.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202312.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202401.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202402.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202403.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202404.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202405.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202406.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202407.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202408.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202409.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202410.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202411.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202412.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202501.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202502.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202503.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\ferny_creek_(dunns_hill)-202504.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202205.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202206.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202207.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202208.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202209.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202210.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202211.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202212.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202301.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202302.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202303.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202304.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202305.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202306.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202307.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202308.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202309.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202310.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202311.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202312.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202401.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202402.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202403.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202404.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202405.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202406.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202407.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202408.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202409.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202410.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202411.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202412.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202501.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202502.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202503.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\frankston-202504.csv
# ✔ Processed: frankston_(ballam_park)-202205.csv
# ✔ Processed: frankston_(ballam_park)-202206.csv
# ✔ Processed: frankston_(ballam_park)-202207.csv
# ✔ Processed: frankston_(ballam_park)-202208.csv
# ✔ Processed: frankston_(ballam_park)-202209.csv
# ✔ Processed: frankston_(ballam_park)-202210.csv
# ✔ Processed: frankston_(ballam_park)-202211.csv
# ✔ Processed: frankston_(ballam_park)-202212.csv
# ✔ Processed: frankston_(ballam_park)-202301.csv
# ✔ Processed: frankston_(ballam_park)-202302.csv
# ✔ Processed: frankston_(ballam_park)-202303.csv
# ✔ Processed: frankston_(ballam_park)-202304.csv
# ✔ Processed: frankston_(ballam_park)-202305.csv
# ✔ Processed: frankston_(ballam_park)-202306.csv
# ✔ Processed: frankston_(ballam_park)-202307.csv
# ✔ Processed: frankston_(ballam_park)-202308.csv
# ✔ Processed: frankston_(ballam_park)-202309.csv
# ✔ Processed: frankston_(ballam_park)-202310.csv
# ✔ Processed: frankston_(ballam_park)-202311.csv
# ✔ Processed: frankston_(ballam_park)-202312.csv
# ✔ Processed: frankston_(ballam_park)-202401.csv
# ✔ Processed: frankston_(ballam_park)-202402.csv
# ✔ Processed: frankston_(ballam_park)-202403.csv
# ✔ Processed: frankston_(ballam_park)-202404.csv
# ✔ Processed: frankston_(ballam_park)-202405.csv
# ✔ Processed: frankston_(ballam_park)-202406.csv
# ✔ Processed: frankston_(ballam_park)-202407.csv
# ✔ Processed: frankston_(ballam_park)-202408.csv
# ✔ Processed: frankston_(ballam_park)-202409.csv
# ✔ Processed: frankston_(ballam_park)-202410.csv
# ✔ Processed: frankston_(ballam_park)-202411.csv
# ✔ Processed: frankston_(ballam_park)-202412.csv
# ✔ Processed: frankston_(ballam_park)-202501.csv
# ✔ Processed: frankston_(ballam_park)-202502.csv
# ✔ Processed: frankston_(ballam_park)-202503.csv
# ✔ Processed: frankston_(ballam_park)-202504.csv
# ✔ Processed: gabo_island_lighthouse-202205.csv
# ✔ Processed: gabo_island_lighthouse-202206.csv
# ✔ Processed: gabo_island_lighthouse-202207.csv
# ✔ Processed: gabo_island_lighthouse-202208.csv
# ✔ Processed: gabo_island_lighthouse-202209.csv
# ✔ Processed: gabo_island_lighthouse-202210.csv
# ✔ Processed: gabo_island_lighthouse-202211.csv
# ✔ Processed: gabo_island_lighthouse-202212.csv
# ✔ Processed: gabo_island_lighthouse-202301.csv
# ✔ Processed: gabo_island_lighthouse-202302.csv
# ✔ Processed: gabo_island_lighthouse-202303.csv
# ✔ Processed: gabo_island_lighthouse-202304.csv
# ✔ Processed: gabo_island_lighthouse-202305.csv
# ✔ Processed: gabo_island_lighthouse-202306.csv
# ✔ Processed: gabo_island_lighthouse-202307.csv
# ✔ Processed: gabo_island_lighthouse-202308.csv
# ✔ Processed: gabo_island_lighthouse-202309.csv
# ✔ Processed: gabo_island_lighthouse-202310.csv
# ✔ Processed: gabo_island_lighthouse-202311.csv
# ✔ Processed: gabo_island_lighthouse-202312.csv
# ✔ Processed: gabo_island_lighthouse-202401.csv
# ✔ Processed: gabo_island_lighthouse-202402.csv
# ✔ Processed: gabo_island_lighthouse-202403.csv
# ✔ Processed: gabo_island_lighthouse-202404.csv
# ✔ Processed: gabo_island_lighthouse-202405.csv
# ✔ Processed: gabo_island_lighthouse-202406.csv
# ✔ Processed: gabo_island_lighthouse-202407.csv
# ✔ Processed: gabo_island_lighthouse-202408.csv
# ✔ Processed: gabo_island_lighthouse-202409.csv
# ✔ Processed: gabo_island_lighthouse-202410.csv
# ✔ Processed: gabo_island_lighthouse-202411.csv
# ✔ Processed: gabo_island_lighthouse-202412.csv
# ✔ Processed: gabo_island_lighthouse-202501.csv
# ✔ Processed: gabo_island_lighthouse-202502.csv
# ✔ Processed: gabo_island_lighthouse-202503.csv
# ✔ Processed: gabo_island_lighthouse-202504.csv
# ✔ Processed: gelantipy-202205.csv
# ✔ Processed: gelantipy-202206.csv
# ✔ Processed: gelantipy-202207.csv
# ✔ Processed: gelantipy-202208.csv
# ✔ Processed: gelantipy-202209.csv
# ✔ Processed: gelantipy-202210.csv
# ✔ Processed: gelantipy-202211.csv
# ✔ Processed: gelantipy-202212.csv
# ✔ Processed: gelantipy-202301.csv
# ✔ Processed: gelantipy-202302.csv
# ✔ Processed: gelantipy-202303.csv
# ✔ Processed: gelantipy-202304.csv
# ✔ Processed: gelantipy-202305.csv
# ✔ Processed: gelantipy-202306.csv
# ✔ Processed: gelantipy-202307.csv
# ✔ Processed: gelantipy-202308.csv
# ✔ Processed: gelantipy-202309.csv
# ✔ Processed: gelantipy-202310.csv
# ✔ Processed: gelantipy-202311.csv
# ✔ Processed: gelantipy-202312.csv
# ✔ Processed: gelantipy-202401.csv
# ✔ Processed: gelantipy-202402.csv
# ✔ Processed: gelantipy-202403.csv
# ✔ Processed: gelantipy-202404.csv
# ✔ Processed: gelantipy-202405.csv
# ✔ Processed: gelantipy-202406.csv
# ✔ Processed: gelantipy-202407.csv
# ✔ Processed: gelantipy-202408.csv
# ✔ Processed: gelantipy-202409.csv
# ✔ Processed: gelantipy-202410.csv
# ✔ Processed: gelantipy-202411.csv
# ✔ Processed: gelantipy-202412.csv
# ✔ Processed: gelantipy-202501.csv
# ✔ Processed: gelantipy-202502.csv
# ✔ Processed: gelantipy-202503.csv
# ✔ Processed: gelantipy-202504.csv
# ✔ Processed: hamilton_airport-202205.csv
# ✔ Processed: hamilton_airport-202206.csv
# ✔ Processed: hamilton_airport-202207.csv
# ✔ Processed: hamilton_airport-202208.csv
# ✔ Processed: hamilton_airport-202209.csv
# ✔ Processed: hamilton_airport-202210.csv
# ✔ Processed: hamilton_airport-202211.csv
# ✔ Processed: hamilton_airport-202212.csv
# ✔ Processed: hamilton_airport-202301.csv
# ✔ Processed: hamilton_airport-202302.csv
# ✔ Processed: hamilton_airport-202303.csv
# ✔ Processed: hamilton_airport-202304.csv
# ✔ Processed: hamilton_airport-202305.csv
# ✔ Processed: hamilton_airport-202306.csv
# ✔ Processed: hamilton_airport-202307.csv
# ✔ Processed: hamilton_airport-202308.csv
# ✔ Processed: hamilton_airport-202309.csv
# ✔ Processed: hamilton_airport-202310.csv
# ✔ Processed: hamilton_airport-202311.csv
# ✔ Processed: hamilton_airport-202312.csv
# ✔ Processed: hamilton_airport-202401.csv
# ✔ Processed: hamilton_airport-202402.csv
# ✔ Processed: hamilton_airport-202403.csv
# ✔ Processed: hamilton_airport-202404.csv
# ✔ Processed: hamilton_airport-202405.csv
# ✔ Processed: hamilton_airport-202406.csv
# ✔ Processed: hamilton_airport-202407.csv
# ✔ Processed: hamilton_airport-202408.csv
# ✔ Processed: hamilton_airport-202409.csv
# ✔ Processed: hamilton_airport-202410.csv
# ✔ Processed: hamilton_airport-202411.csv
# ✔ Processed: hamilton_airport-202412.csv
# ✔ Processed: hamilton_airport-202501.csv
# ✔ Processed: hamilton_airport-202502.csv
# ✔ Processed: hamilton_airport-202503.csv
# ✔ Processed: hamilton_airport-202504.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202205.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202206.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202207.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202208.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202209.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202210.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202211.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202212.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202301.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202302.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202303.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202304.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202305.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202306.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202307.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202308.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202309.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202310.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202311.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202312.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202401.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202402.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202403.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202404.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202405.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202406.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202407.csv
# [Skip] Empty file: E:\study\meteoroData_raw\vic\glenlitta_avenue_-_micromac_site-202408.csv
# ...
# ✔ Processed: alva_beach-202308.csv
# ✔ Processed: alva_beach-202309.csv
# ✔ Processed: alva_beach-202310.csv
# ✔ Processed: alva_beach-202311.csv
# ✔ Processed: alva_beach-202312.csv
# ✔ Processed: alva_beach-202401.csv
# ✔ Processed: alva_beach-202402.csv
# ✔ Processed: alva_beach-202403.csv
# ✔ Processed: alva_beach-202404.csv
# ✔ Processed: alva_beach-202405.csv
# ✔ Processed: alva_beach-202406.csv
# ✔ Processed: alva_beach-202407.csv
# ✔ Processed: alva_beach-202408.csv
# ✔ Processed: alva_beach-202409.csv
# ✔ Processed: alva_beach-202410.csv
# ✔ Processed: alva_beach-202411.csv
# ✔ Processed: alva_beach-202412.csv
# ✔ Processed: alva_beach-202501.csv
# ✔ Processed: alva_beach-202502.csv
# ✔ Processed: alva_beach-202503.csv
# ✔ Processed: alva_beach-202504.csv
# ✔ Processed: amberley_amo-202205.csv
# ✔ Processed: amberley_amo-202206.csv
# ✔ Processed: amberley_amo-202207.csv
# ✔ Processed: amberley_amo-202208.csv
# ✔ Processed: amberley_amo-202209.csv
# ✔ Processed: amberley_amo-202210.csv
# ✔ Processed: amberley_amo-202211.csv
# ✔ Processed: amberley_amo-202212.csv
# ✔ Processed: amberley_amo-202301.csv
# ✔ Processed: amberley_amo-202302.csv
# ✔ Processed: amberley_amo-202303.csv
# ✔ Processed: amberley_amo-202304.csv
# ✔ Processed: amberley_amo-202305.csv
# ✔ Processed: amberley_amo-202306.csv
# ✔ Processed: amberley_amo-202307.csv
# ✔ Processed: amberley_amo-202308.csv
# ✔ Processed: amberley_amo-202309.csv
# ✔ Processed: amberley_amo-202310.csv
# ✔ Processed: amberley_amo-202311.csv
# ✔ Processed: amberley_amo-202312.csv
# ✔ Processed: amberley_amo-202401.csv
# ✔ Processed: amberley_amo-202402.csv
# ✔ Processed: amberley_amo-202403.csv
# ✔ Processed: amberley_amo-202404.csv
# ✔ Processed: amberley_amo-202405.csv
# ✔ Processed: amberley_amo-202406.csv
# ✔ Processed: amberley_amo-202407.csv
# ✔ Processed: amberley_amo-202408.csv
# ✔ Processed: amberley_amo-202409.csv
# ✔ Processed: amberley_amo-202410.csv
# ✔ Processed: amberley_amo-202411.csv
# ✔ Processed: amberley_amo-202412.csv
# ✔ Processed: amberley_amo-202501.csv
# ✔ Processed: amberley_amo-202502.csv
# ✔ Processed: amberley_amo-202503.csv
# ✔ Processed: amberley_amo-202504.csv
# ✔ Processed: applethorpe-202205.csv
# ✔ Processed: applethorpe-202206.csv
# ✔ Processed: applethorpe-202207.csv
# ✔ Processed: applethorpe-202208.csv
# ✔ Processed: applethorpe-202209.csv
# ✔ Processed: applethorpe-202210.csv
# ✔ Processed: applethorpe-202211.csv
# ✔ Processed: applethorpe-202212.csv
# ✔ Processed: applethorpe-202301.csv
# ✔ Processed: applethorpe-202302.csv
# ✔ Processed: applethorpe-202303.csv
# ✔ Processed: applethorpe-202304.csv
# ✔ Processed: applethorpe-202305.csv
# ✔ Processed: applethorpe-202306.csv
# ✔ Processed: applethorpe-202307.csv
# ✔ Processed: applethorpe-202308.csv
# ✔ Processed: applethorpe-202309.csv
# ✔ Processed: applethorpe-202310.csv
# ✔ Processed: applethorpe-202311.csv
# ✔ Processed: applethorpe-202312.csv
# ✔ Processed: applethorpe-202401.csv
# ✔ Processed: applethorpe-202402.csv
# ✔ Processed: applethorpe-202403.csv
# ✔ Processed: applethorpe-202404.csv
# ✔ Processed: applethorpe-202405.csv
# ✔ Processed: applethorpe-202406.csv
# ✔ Processed: applethorpe-202407.csv
# ✔ Processed: applethorpe-202408.csv
# ✔ Processed: applethorpe-202409.csv
# ✔ Processed: applethorpe-202410.csv
# ✔ Processed: applethorpe-202411.csv
# ✔ Processed: applethorpe-202412.csv
# ✔ Processed: applethorpe-202501.csv
# ✔ Processed: applethorpe-202502.csv
# ✔ Processed: applethorpe-202503.csv
# ✔ Processed: applethorpe-202504.csv
# ✔ Processed: archerfield_airport-202205.csv
# ✔ Processed: archerfield_airport-202206.csv
# ✔ Processed: archerfield_airport-202207.csv
# ✔ Processed: archerfield_airport-202208.csv
# ✔ Processed: archerfield_airport-202209.csv
# ✔ Processed: archerfield_airport-202210.csv
# ✔ Processed: archerfield_airport-202211.csv
# ✔ Processed: archerfield_airport-202212.csv
# ✔ Processed: archerfield_airport-202301.csv
# ✔ Processed: archerfield_airport-202302.csv
# ✔ Processed: archerfield_airport-202303.csv
# ✔ Processed: archerfield_airport-202304.csv
# ✔ Processed: archerfield_airport-202305.csv
# ✔ Processed: archerfield_airport-202306.csv
# ✔ Processed: archerfield_airport-202307.csv
# ✔ Processed: archerfield_airport-202308.csv
# ✔ Processed: archerfield_airport-202309.csv
# ✔ Processed: archerfield_airport-202310.csv
# ✔ Processed: archerfield_airport-202311.csv
# ✔ Processed: archerfield_airport-202312.csv
# ✔ Processed: archerfield_airport-202401.csv
# ✔ Processed: archerfield_airport-202402.csv
# ✔ Processed: archerfield_airport-202403.csv
# ✔ Processed: archerfield_airport-202404.csv
# ✔ Processed: archerfield_airport-202405.csv
# ✔ Processed: archerfield_airport-202406.csv
# ✔ Processed: archerfield_airport-202407.csv
# ✔ Processed: archerfield_airport-202408.csv
# ✔ Processed: archerfield_airport-202409.csv
# ✔ Processed: archerfield_airport-202410.csv
# ✔ Processed: archerfield_airport-202411.csv
# ✔ Processed: archerfield_airport-202412.csv
# ✔ Processed: archerfield_airport-202501.csv
# ✔ Processed: archerfield_airport-202502.csv
# ✔ Processed: archerfield_airport-202503.csv
# ✔ Processed: archerfield_airport-202504.csv
# ✔ Processed: ayr_dpi_research_stn-202205.csv
# ✔ Processed: ayr_dpi_research_stn-202206.csv
# ✔ Processed: ayr_dpi_research_stn-202207.csv
# ✔ Processed: ayr_dpi_research_stn-202208.csv
# ✔ Processed: ayr_dpi_research_stn-202209.csv
# ✔ Processed: ayr_dpi_research_stn-202210.csv
# ✔ Processed: ayr_dpi_research_stn-202211.csv
# ✔ Processed: ayr_dpi_research_stn-202212.csv
# ✔ Processed: ayr_dpi_research_stn-202301.csv
# ✔ Processed: ayr_dpi_research_stn-202302.csv
# ✔ Processed: ayr_dpi_research_stn-202303.csv
# ✔ Processed: ayr_dpi_research_stn-202304.csv
# ✔ Processed: ayr_dpi_research_stn-202305.csv
# ✔ Processed: ayr_dpi_research_stn-202306.csv
# ✔ Processed: ayr_dpi_research_stn-202307.csv
# ✔ Processed: ayr_dpi_research_stn-202308.csv
# ✔ Processed: ayr_dpi_research_stn-202309.csv
# ✔ Processed: ayr_dpi_research_stn-202310.csv
# ✔ Processed: ayr_dpi_research_stn-202311.csv
# ✔ Processed: ayr_dpi_research_stn-202312.csv
# ✔ Processed: ayr_dpi_research_stn-202401.csv
# ✔ Processed: ayr_dpi_research_stn-202402.csv
# ✔ Processed: ayr_dpi_research_stn-202403.csv
# ✔ Processed: ayr_dpi_research_stn-202404.csv
# ✔ Processed: ayr_dpi_research_stn-202405.csv
# ✔ Processed: ayr_dpi_research_stn-202406.csv
# ✔ Processed: ayr_dpi_research_stn-202407.csv
# ✔ Processed: ayr_dpi_research_stn-202408.csv
# ✔ Processed: ayr_dpi_research_stn-202409.csv
# ✔ Processed: ayr_dpi_research_stn-202410.csv
# ✔ Processed: ayr_dpi_research_stn-202411.csv
# ✔ Processed: ayr_dpi_research_stn-202412.csv
# ✔ Processed: ayr_dpi_research_stn-202501.csv
# ✔ Processed: ayr_dpi_research_stn-202502.csv
# ✔ Processed: ayr_dpi_research_stn-202503.csv
# ✔ Processed: ayr_dpi_research_stn-202504.csv
# ✔ Processed: ballera_gas_field-202205.csv
# ✔ Processed: ballera_gas_field-202206.csv
# ✔ Processed: ballera_gas_field-202207.csv
# ✔ Processed: ballera_gas_field-202208.csv
# ✔ Processed: ballera_gas_field-202209.csv
# ✔ Processed: ballera_gas_field-202210.csv
# ✔ Processed: ballera_gas_field-202211.csv
# ✔ Processed: ballera_gas_field-202212.csv
# ✔ Processed: ballera_gas_field-202301.csv
# ✔ Processed: ballera_gas_field-202302.csv
# ✔ Processed: ballera_gas_field-202303.csv
# ✔ Processed: ballera_gas_field-202304.csv
# ✔ Processed: ballera_gas_field-202305.csv
# ✔ Processed: ballera_gas_field-202306.csv
# ✔ Processed: ballera_gas_field-202307.csv
# ✔ Processed: ballera_gas_field-202308.csv
# ✔ Processed: ballera_gas_field-202309.csv
# ✔ Processed: ballera_gas_field-202310.csv
# ✔ Processed: ballera_gas_field-202311.csv
# ✔ Processed: ballera_gas_field-202312.csv
# ✔ Processed: ballera_gas_field-202401.csv
# ✔ Processed: ballera_gas_field-202402.csv
# ✔ Processed: ballera_gas_field-202403.csv
# ✔ Processed: ballera_gas_field-202404.csv
# ✔ Processed: ballera_gas_field-202405.csv
# ✔ Processed: ballera_gas_field-202406.csv
# ✔ Processed: ballera_gas_field-202407.csv
# ✔ Processed: ballera_gas_field-202408.csv
# ✔ Processed: ballera_gas_field-202409.csv
# ✔ Processed: ballera_gas_field-202410.csv
# ✔ Processed: ballera_gas_field-202411.csv
# ✔ Processed: ballera_gas_field-202412.csv
# ✔ Processed: ballera_gas_field-202501.csv
# ✔ Processed: ballera_gas_field-202502.csv
# ✔ Processed: ballera_gas_field-202503.csv
# ✔ Processed: ballera_gas_field-202504.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202205.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202206.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202207.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202208.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202209.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202210.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202211.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202212.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202301.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202302.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202303.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202304.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202305.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202306.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202307.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202308.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202309.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202310.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202311.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202312.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202401.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202402.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202403.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202404.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202405.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202406.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202407.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202408.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202409.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202410.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202411.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202412.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202501.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202502.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202503.csv
# [Skip] Empty file: E:\study\meteoroData_raw\qld\banana_bank_north_beacon-202504.csv
# ✔ Processed: beaudesert_drumley_street-202205.csv
# ✔ Processed: beaudesert_drumley_street-202206.csv
# ✔ Processed: beaudesert_drumley_street-202207.csv
# ✔ Processed: beaudesert_drumley_street-202208.csv
# ✔ Processed: beaudesert_drumley_street-202209.csv
# ✔ Processed: beaudesert_drumley_street-202210.csv
# ✔ Processed: beaudesert_drumley_street-202211.csv
# ✔ Processed: beaudesert_drumley_street-202212.csv
# ✔ Processed: beaudesert_drumley_street-202301.csv
# ✔ Processed: beaudesert_drumley_street-202302.csv
# ✔ Processed: beaudesert_drumley_street-202303.csv
# ✔ Processed: beaudesert_drumley_street-202304.csv
# ✔ Processed: beaudesert_drumley_street-202305.csv
# ✔ Processed: beaudesert_drumley_street-202306.csv
# ✔ Processed: beaudesert_drumley_street-202307.csv
# ✔ Processed: beaudesert_drumley_street-202308.csv
# ✔ Processed: beaudesert_drumley_street-202309.csv
# ✔ Processed: beaudesert_drumley_street-202310.csv
# ✔ Processed: beaudesert_drumley_street-202311.csv
# ✔ Processed: beaudesert_drumley_street-202312.csv
# ✔ Processed: beaudesert_drumley_street-202401.csv
# ✔ Processed: beaudesert_drumley_street-202402.csv
# ✔ Processed: beaudesert_drumley_street-202403.csv
# ✔ Processed: beaudesert_drumley_street-202404.csv
# ✔ Processed: beaudesert_drumley_street-202405.csv
# ✔ Processed: beaudesert_drumley_street-202406.csv
# ✔ Processed: beaudesert_drumley_street-202407.csv
# ✔ Processed: beaudesert_drumley_street-202408.csv
# ✔ Processed: beaudesert_drumley_street-202409.csv
# ✔ Processed: beaudesert_drumley_street-202410.csv
# ✔ Processed: beaudesert_drumley_street-202411.csv
# ✔ Processed: beaudesert_drumley_street-202412.csv
# ✔ Processed: beaudesert_drumley_street-202501.csv
# ✔ Processed: beaudesert_drumley_street-202502.csv
# ✔ Processed: beaudesert_drumley_street-202503.csv
# ✔ Processed: beaudesert_drumley_street-202504.csv
# ✔ Processed: beerburrum_forest_station-202205.csv
# ✔ Processed: beerburrum_forest_station-202206.csv
# ✔ Processed: beerburrum_forest_station-202207.csv
# ✔ Processed: beerburrum_forest_station-202208.csv
# ✔ Processed: beerburrum_forest_station-202209.csv
# ✔ Processed: beerburrum_forest_station-202210.csv
# ✔ Processed: beerburrum_forest_station-202211.csv
# ✔ Processed: beerburrum_forest_station-202212.csv
# ✔ Processed: beerburrum_forest_station-202301.csv
# ✔ Processed: beerburrum_forest_station-202302.csv
# ✔ Processed: beerburrum_forest_station-202303.csv
# ✔ Processed: beerburrum_forest_station-202304.csv
# ✔ Processed: beerburrum_forest_station-202305.csv
# ✔ Processed: beerburrum_forest_station-202306.csv
# ✔ Processed: beerburrum_forest_station-202307.csv
# ✔ Processed: beerburrum_forest_station-202308.csv
# ✔ Processed: beerburrum_forest_station-202309.csv
# ✔ Processed: beerburrum_forest_station-202310.csv
# ✔ Processed: beerburrum_forest_station-202311.csv
# ✔ Processed: beerburrum_forest_station-202312.csv
# ✔ Processed: beerburrum_forest_station-202401.csv
# ✔ Processed: beerburrum_forest_station-202402.csv
# ✔ Processed: beerburrum_forest_station-202403.csv
# ✔ Processed: beerburrum_forest_station-202404.csv
# ✔ Processed: beerburrum_forest_station-202405.csv
# ✔ Processed: beerburrum_forest_station-202406.csv
# ✔ Processed: beerburrum_forest_station-202407.csv
# ✔ Processed: beerburrum_forest_station-202408.csv
# ✔ Processed: beerburrum_forest_station-202409.csv
# ✔ Processed: beerburrum_forest_station-202410.csv
# ✔ Processed: beerburrum_forest_station-202411.csv
# ✔ Processed: beerburrum_forest_station-202412.csv
# ✔ Processed: beerburrum_forest_station-202501.csv
# ✔ Processed: beerburrum_forest_station-202502.csv
# ✔ Processed: beerburrum_forest_station-202503.csv
# ✔ Processed: beerburrum_forest_station-202504.csv
# ✔ Processed: birdsville_airport-202205.csv
# ✔ Processed: birdsville_airport-202206.csv
# ✔ Processed: birdsville_airport-202207.csv
# ✔ Processed: birdsville_airport-202208.csv
# ✔ Processed: birdsville_airport-202209.csv
# ✔ Processed: birdsville_airport-202210.csv
# ✔ Processed: birdsville_airport-202211.csv
# ✔ Processed: birdsville_airport-202212.csv
# ✔ Processed: birdsville_airport-202301.csv
# ✔ Processed: birdsville_airport-202302.csv
# ✔ Processed: birdsville_airport-202303.csv
# ✔ Processed: birdsville_airport-202304.csv
# ✔ Processed: birdsville_airport-202305.csv
# ✔ Processed: birdsville_airport-202306.csv
# ✔ Processed: birdsville_airport-202307.csv
# ✔ Processed: birdsville_airport-202308.csv
# ✔ Processed: birdsville_airport-202309.csv
# ✔ Processed: birdsville_airport-202310.csv
# ✔ Processed: birdsville_airport-202311.csv
# ✔ Processed: birdsville_airport-202312.csv
# ✔ Processed: birdsville_airport-202401.csv
# ✔ Processed: birdsville_airport-202402.csv
# ✔ Processed: birdsville_airport-202403.csv
# ✔ Processed: birdsville_airport-202404.csv
# ✔ Processed: birdsville_airport-202405.csv
# ✔ Processed: birdsville_airport-202406.csv
# ✔ Processed: birdsville_airport-202407.csv
# ✔ Processed: birdsville_airport-202408.csv
#
# ✅ Done! 320949 records written to: E:\study\meteoroData_clean\all_states_weather.csv

# %% [markdown]
# ### Check V1

# %%
import pandas as pd

# Load the cleaned, merged weather data
file_path = r"E:\study\meteoroData_clean\all_states_weather_v1.csv"
df = pd.read_csv(file_path, encoding="utf-8")

# Preview the first few rows
df.head(50)
# Out:
#           date state         station max_Temperature_C min_Temperature_C  \
# 0   2022-11-01   VIC  AVALON AIRPORT              13.8               6.4
# 1   2022-11-02   VIC  AVALON AIRPORT              15.4               5.3
# 2   2022-11-03   VIC  AVALON AIRPORT              15.1               6.2
# 3   2022-11-04   VIC  AVALON AIRPORT              17.9               7.3
# 4   2022-11-05   VIC  AVALON AIRPORT              21.4              10.1
# 5   2022-11-06   VIC  AVALON AIRPORT              25.5               8.1
# 6   2022-11-07   VIC  AVALON AIRPORT              25.7              12.9
# 7   2022-11-08   VIC  AVALON AIRPORT              26.4              10.8
# 8   2022-11-09   VIC  AVALON AIRPORT              29.4              13.1
# 9   2022-11-10   VIC  AVALON AIRPORT              25.8              16.9
# 10  2022-11-11   VIC  AVALON AIRPORT              17.6              14.4
# 11  2022-11-12   VIC  AVALON AIRPORT              18.9              12.8
# 12  2022-11-13   VIC  AVALON AIRPORT              25.6              14.0
# 13  2022-11-14   VIC  AVALON AIRPORT              17.0              12.5
# 14  2022-11-15   VIC  AVALON AIRPORT              13.8               6.9
# 15  2022-11-16   VIC  AVALON AIRPORT              15.2               5.0
# 16  2022-11-17   VIC  AVALON AIRPORT              17.5               7.6
# 17  2022-11-18   VIC  AVALON AIRPORT              21.3               8.6
# 18  2022-11-19   VIC  AVALON AIRPORT              21.7              14.1
# 19  2022-11-20   VIC  AVALON AIRPORT              19.9              10.6
# 20  2022-11-21   VIC  AVALON AIRPORT              13.7               7.5
# 21  2022-11-22   VIC  AVALON AIRPORT              18.3               6.9
# 22  2022-11-23   VIC  AVALON AIRPORT              18.9              10.7
# 23  2022-11-24   VIC  AVALON AIRPORT              19.6              10.2
# 24  2022-11-25   VIC  AVALON AIRPORT              20.2               7.8
# 25  2022-11-26   VIC  AVALON AIRPORT              27.4               9.1
# 26  2022-11-27   VIC  AVALON AIRPORT              20.3              12.7
# 27  2022-11-28   VIC  AVALON AIRPORT              19.7               7.3
# 28  2022-11-29   VIC  AVALON AIRPORT              19.0              10.2
# 29  2022-11-30   VIC  AVALON AIRPORT              20.0               7.6
# 30         NaN   VIC         Totals:               NaN               NaN
# 31  2022-12-01   VIC  AVALON AIRPORT              19.7              11.3
# 32  2022-12-02   VIC  AVALON AIRPORT              22.1               9.7
# 33  2022-12-03   VIC  AVALON AIRPORT              30.7              10.3
# 34  2022-12-04   VIC  AVALON AIRPORT              34.5              13.1
# 35  2022-12-05   VIC  AVALON AIRPORT              19.2              14.9
# 36  2022-12-06   VIC  AVALON AIRPORT              20.6              11.7
# 37  2022-12-07   VIC  AVALON AIRPORT              20.8               9.8
# 38  2022-12-08   VIC  AVALON AIRPORT              18.0               7.1
# 39  2022-12-09   VIC  AVALON AIRPORT              18.3               6.9
# 40  2022-12-10   VIC  AVALON AIRPORT              24.1               4.6
# 41  2022-12-11   VIC  AVALON AIRPORT              30.2              12.3
# 42  2022-12-12   VIC  AVALON AIRPORT              17.6              10.8
# 43  2022-12-13   VIC  AVALON AIRPORT              18.2              10.0
# 44  2022-12-14   VIC  AVALON AIRPORT              17.6               7.6
# 45  2022-12-15   VIC  AVALON AIRPORT              17.8              11.2
# 46  2022-12-16   VIC  AVALON AIRPORT              20.2               9.8
# 47  2022-12-17   VIC  AVALON AIRPORT              21.0              10.0
# 48  2022-12-18   VIC  AVALON AIRPORT              21.9              12.9
# 49  2022-12-19   VIC  AVALON AIRPORT              24.5              12.4
#
#    max_Humidity_pct min_Humidity_pct wind_speed_m_s
# 0              92.0             54.0           6.69
# 1              94.0             55.0           7.58
# 2              94.0             60.0           3.65
# 3              97.0             58.0            3.5
# 4              97.0             58.0            2.3
# 5              98.0             36.0           2.91
# 6              95.0             41.0           2.55
# 7              98.0             48.0            3.0
# 8              96.0             37.0           4.06
# 9              90.0             50.0           4.72
# 10             97.0             84.0           4.18
# 11             95.0             67.0           3.66
# 12             98.0             58.0            4.1
# 13             97.0             57.0            7.8
# 14             93.0             60.0           6.06
# 15             92.0             56.0           6.44
# 16             97.0             60.0           4.57
# 17             91.0             51.0           3.33
# 18             97.0             58.0           5.38
# 19             95.0             44.0           9.34
# 20             91.0             57.0          11.31
# 21             94.0             62.0           9.18
# 22             97.0             60.0           5.32
# 23             94.0             53.0           4.11
# 24             97.0             55.0            2.9
# 25             96.0             35.0           5.16
# 26             90.0             52.0           5.77
# 27             92.0             48.0           6.36
# 28             94.0             48.0           4.91
# 29             96.0             55.0           3.83
# 30              NaN              NaN            NaN
# 31             93.0             57.0           4.29
# 32             95.0             56.0           3.61
# 33             97.0             42.0           3.21
# 34             95.0             16.0           4.72
# 35             85.0             57.0           9.41
# 36             95.0             51.0           4.69
# 37             95.0             38.0           6.01
# 38             85.0             44.0           7.84
# 39             83.0             44.0           5.45
# 40             94.0             38.0           2.94
# 41             95.0             28.0           5.07
# 42             97.0             60.0           9.52
# 43             92.0             43.0           8.81
# 44             94.0             48.0           8.79
# 45             83.0             49.0            8.2
# 46             87.0             46.0           5.79
# 47             95.0             57.0           5.73
# 48             78.0             48.0           8.29
# 49             85.0             31.0           6.02

# %%
df.tail(50)
# Out:
#               date state             station max_Temperature_C  \
# 320899  2024-07-15   QLD  BIRDSVILLE AIRPORT              19.2
# 320900  2024-07-16   QLD  BIRDSVILLE AIRPORT              17.8
# 320901  2024-07-17   QLD  BIRDSVILLE AIRPORT              17.8
# 320902  2024-07-18   QLD  BIRDSVILLE AIRPORT              17.4
# 320903  2024-07-19   QLD  BIRDSVILLE AIRPORT              21.1
# 320904  2024-07-20   QLD  BIRDSVILLE AIRPORT              18.7
# 320905  2024-07-21   QLD  BIRDSVILLE AIRPORT              20.0
# 320906  2024-07-22   QLD  BIRDSVILLE AIRPORT              21.7
# 320907  2024-07-23   QLD  BIRDSVILLE AIRPORT              23.4
# 320908  2024-07-24   QLD  BIRDSVILLE AIRPORT              26.5
# 320909  2024-07-25   QLD  BIRDSVILLE AIRPORT              25.0
# 320910  2024-07-26   QLD  BIRDSVILLE AIRPORT              19.8
# 320911  2024-07-27   QLD  BIRDSVILLE AIRPORT              21.0
# 320912  2024-07-28   QLD  BIRDSVILLE AIRPORT              19.0
# 320913  2024-07-29   QLD  BIRDSVILLE AIRPORT              18.8
# 320914  2024-07-30   QLD  BIRDSVILLE AIRPORT              21.2
# 320915  2024-07-31   QLD  BIRDSVILLE AIRPORT              21.0
# 320916         NaN   QLD             Totals:               NaN
# 320917  2024-08-01   QLD  BIRDSVILLE AIRPORT              23.9
# 320918  2024-08-02   QLD  BIRDSVILLE AIRPORT              24.8
# 320919  2024-08-03   QLD  BIRDSVILLE AIRPORT              26.2
# 320920  2024-08-04   QLD  BIRDSVILLE AIRPORT              23.7
# 320921  2024-08-05   QLD  BIRDSVILLE AIRPORT              22.2
# 320922  2024-08-06   QLD  BIRDSVILLE AIRPORT              21.2
# 320923  2024-08-07   QLD  BIRDSVILLE AIRPORT              21.2
# 320924  2024-08-08   QLD  BIRDSVILLE AIRPORT              23.2
# 320925  2024-08-09   QLD  BIRDSVILLE AIRPORT              25.5
# 320926  2024-08-10   QLD  BIRDSVILLE AIRPORT              26.3
# 320927  2024-08-11   QLD  BIRDSVILLE AIRPORT              27.8
# 320928  2024-08-12   QLD  BIRDSVILLE AIRPORT              25.4
# 320929  2024-08-13   QLD  BIRDSVILLE AIRPORT              27.3
# 320930  2024-08-14   QLD  BIRDSVILLE AIRPORT              27.6
# 320931  2024-08-15   QLD  BIRDSVILLE AIRPORT              28.7
# 320932  2024-08-16   QLD  BIRDSVILLE AIRPORT              29.4
# 320933  2024-08-17   QLD  BIRDSVILLE AIRPORT              24.5
# 320934  2024-08-18   QLD  BIRDSVILLE AIRPORT              25.0
# 320935  2024-08-19   QLD  BIRDSVILLE AIRPORT              30.1
# 320936  2024-08-20   QLD  BIRDSVILLE AIRPORT              31.6
# 320937  2024-08-21   QLD  BIRDSVILLE AIRPORT              30.3
# 320938  2024-08-22   QLD  BIRDSVILLE AIRPORT              33.4
# 320939  2024-08-23   QLD  BIRDSVILLE AIRPORT              36.8
# 320940  2024-08-24   QLD  BIRDSVILLE AIRPORT              37.7
# 320941  2024-08-25   QLD  BIRDSVILLE AIRPORT              38.4
# 320942  2024-08-26   QLD  BIRDSVILLE AIRPORT              28.8
# 320943  2024-08-27   QLD  BIRDSVILLE AIRPORT              32.4
# 320944  2024-08-28   QLD  BIRDSVILLE AIRPORT              36.3
# 320945  2024-08-29   QLD  BIRDSVILLE AIRPORT              35.6
# 320946  2024-08-30   QLD  BIRDSVILLE AIRPORT              39.7
# 320947  2024-08-31   QLD  BIRDSVILLE AIRPORT              33.1
# 320948         NaN   QLD             Totals:               NaN
#
#        min_Temperature_C max_Humidity_pct min_Humidity_pct wind_speed_m_s
# 320899               6.5             93.0             44.0           3.74
# 320900               7.3             86.0             43.0           5.08
# 320901               8.6             74.0             41.0           5.48
# 320902               5.7             90.0             42.0           2.66
# 320903               4.7             90.0             27.0           4.84
# 320904               7.9             74.0             34.0           5.78
# 320905               5.2             86.0             34.0           3.11
# 320906               5.8             86.0             31.0           3.11
# 320907               6.1             85.0             27.0           3.28
# 320908               6.7             77.0             25.0           4.59
# 320909               9.9             82.0             24.0           4.48
# 320910              11.3             81.0             49.0            4.1
# 320911              12.1             94.0             29.0           3.59
# 320912               7.5             85.0             36.0           4.83
# 320913               3.2             80.0             22.0           4.55
# 320914               3.2             78.0             24.0           4.41
# 320915               4.2             67.0             20.0           4.44
# 320916               NaN              NaN              NaN            NaN
# 320917               3.4               74               25           3.79
# 320918               8.2
# 320919               6.2               68               17           3.62
# 320920              13.5               57               25           3.90
# 320921              11.8               92               46           4.70
# 320922               6.8               95               39           3.71
# 320923               7.1               94               34           3.13
# 320924               6.5               83               28           2.09
# 320925               7.0               77               20           3.36
# 320926               7.0               81               29           4.39
# 320927              10.2               69               28           4.00
# 320928              10.9               81               40           3.46
# 320929              10.9               78               31           2.88
# 320930              12.3               75               31           2.64
# 320931              12.4               73               30           2.94
# 320932              11.8               76               22           4.51
# 320933               9.0               58               22           4.21
# 320934               7.0               66               19           2.21
# 320935               8.9               59               13           4.39
# 320936              15.7               39               15           4.73
# 320937              12.0               54               19           2.84
# 320938              15.1               47               17           4.26
# 320939              16.2               46               16           7.01
# 320940              23.2               36               14           7.03
# 320941              22.4               33               14           7.68
# 320942              16.0               51               17           5.41
# 320943              10.3               55               14           2.62
# 320944              14.8               47               11           2.31
# 320945              15.1               47               13           3.18
# 320946              17.7               34               12           6.52
# 320947              17.3               52               24           4.88
# 320948               NaN              NaN              NaN            NaN

# %% [markdown]
# ### V2  regular cleaning -  EDA(Exploratory data analysis) - Clean the total line

# %%
# 1. Paths
CLEANED_DIR = r"E:\study\meteoroData_clean"
v1_path     = os.path.join(CLEANED_DIR, "all_states_weather_v1.csv")
v2_path     = os.path.join(CLEANED_DIR, "all_states_weather_v2.csv")

# 2. Load v1
df = pd.read_csv(v1_path, encoding="utf-8")

# 3. Drop any row where station == 'Totals:'
clean_df = df[df["station"] != "Totals:"].copy()

# 4. (Optional) Report how many rows were removed
removed = len(df) - len(clean_df)
print(f"Removed {removed} summary rows, {len(clean_df)} remain.")

# 5. Save to v2
clean_df.to_csv(v2_path, index=False, encoding="utf-8")
print(f"Written cleaned data to: {v2_path}")
# Out:
# Removed 10238 summary rows, 310711 remain.
# Written cleaned data to: E:\study\meteoroData_clean\all_states_weather_v2.csv

# %% [markdown]
# ### check v2

# %%
# Load the cleaned, merged weather data
file_path = r"E:\study\meteoroData_clean\all_states_weather_v2.csv"
df = pd.read_csv(file_path, encoding="utf-8")

# Preview the first few rows
df.head(50)
# Out:
#           date state         station max_Temperature_C min_Temperature_C  \
# 0   2022-11-01   VIC  AVALON AIRPORT              13.8               6.4
# 1   2022-11-02   VIC  AVALON AIRPORT              15.4               5.3
# 2   2022-11-03   VIC  AVALON AIRPORT              15.1               6.2
# 3   2022-11-04   VIC  AVALON AIRPORT              17.9               7.3
# 4   2022-11-05   VIC  AVALON AIRPORT              21.4              10.1
# 5   2022-11-06   VIC  AVALON AIRPORT              25.5               8.1
# 6   2022-11-07   VIC  AVALON AIRPORT              25.7              12.9
# 7   2022-11-08   VIC  AVALON AIRPORT              26.4              10.8
# 8   2022-11-09   VIC  AVALON AIRPORT              29.4              13.1
# 9   2022-11-10   VIC  AVALON AIRPORT              25.8              16.9
# 10  2022-11-11   VIC  AVALON AIRPORT              17.6              14.4
# 11  2022-11-12   VIC  AVALON AIRPORT              18.9              12.8
# 12  2022-11-13   VIC  AVALON AIRPORT              25.6              14.0
# 13  2022-11-14   VIC  AVALON AIRPORT              17.0              12.5
# 14  2022-11-15   VIC  AVALON AIRPORT              13.8               6.9
# 15  2022-11-16   VIC  AVALON AIRPORT              15.2               5.0
# 16  2022-11-17   VIC  AVALON AIRPORT              17.5               7.6
# 17  2022-11-18   VIC  AVALON AIRPORT              21.3               8.6
# 18  2022-11-19   VIC  AVALON AIRPORT              21.7              14.1
# 19  2022-11-20   VIC  AVALON AIRPORT              19.9              10.6
# 20  2022-11-21   VIC  AVALON AIRPORT              13.7               7.5
# 21  2022-11-22   VIC  AVALON AIRPORT              18.3               6.9
# 22  2022-11-23   VIC  AVALON AIRPORT              18.9              10.7
# 23  2022-11-24   VIC  AVALON AIRPORT              19.6              10.2
# 24  2022-11-25   VIC  AVALON AIRPORT              20.2               7.8
# 25  2022-11-26   VIC  AVALON AIRPORT              27.4               9.1
# 26  2022-11-27   VIC  AVALON AIRPORT              20.3              12.7
# 27  2022-11-28   VIC  AVALON AIRPORT              19.7               7.3
# 28  2022-11-29   VIC  AVALON AIRPORT              19.0              10.2
# 29  2022-11-30   VIC  AVALON AIRPORT              20.0               7.6
# 30  2022-12-01   VIC  AVALON AIRPORT              19.7              11.3
# 31  2022-12-02   VIC  AVALON AIRPORT              22.1               9.7
# 32  2022-12-03   VIC  AVALON AIRPORT              30.7              10.3
# 33  2022-12-04   VIC  AVALON AIRPORT              34.5              13.1
# 34  2022-12-05   VIC  AVALON AIRPORT              19.2              14.9
# 35  2022-12-06   VIC  AVALON AIRPORT              20.6              11.7
# 36  2022-12-07   VIC  AVALON AIRPORT              20.8               9.8
# 37  2022-12-08   VIC  AVALON AIRPORT              18.0               7.1
# 38  2022-12-09   VIC  AVALON AIRPORT              18.3               6.9
# 39  2022-12-10   VIC  AVALON AIRPORT              24.1               4.6
# 40  2022-12-11   VIC  AVALON AIRPORT              30.2              12.3
# 41  2022-12-12   VIC  AVALON AIRPORT              17.6              10.8
# 42  2022-12-13   VIC  AVALON AIRPORT              18.2              10.0
# 43  2022-12-14   VIC  AVALON AIRPORT              17.6               7.6
# 44  2022-12-15   VIC  AVALON AIRPORT              17.8              11.2
# 45  2022-12-16   VIC  AVALON AIRPORT              20.2               9.8
# 46  2022-12-17   VIC  AVALON AIRPORT              21.0              10.0
# 47  2022-12-18   VIC  AVALON AIRPORT              21.9              12.9
# 48  2022-12-19   VIC  AVALON AIRPORT              24.5              12.4
# 49  2022-12-20   VIC  AVALON AIRPORT              24.9              11.8
#
#    max_Humidity_pct min_Humidity_pct wind_speed_m_s
# 0              92.0             54.0           6.69
# 1              94.0             55.0           7.58
# 2              94.0             60.0           3.65
# 3              97.0             58.0            3.5
# 4              97.0             58.0            2.3
# 5              98.0             36.0           2.91
# 6              95.0             41.0           2.55
# 7              98.0             48.0            3.0
# 8              96.0             37.0           4.06
# 9              90.0             50.0           4.72
# 10             97.0             84.0           4.18
# 11             95.0             67.0           3.66
# 12             98.0             58.0            4.1
# 13             97.0             57.0            7.8
# 14             93.0             60.0           6.06
# 15             92.0             56.0           6.44
# 16             97.0             60.0           4.57
# 17             91.0             51.0           3.33
# 18             97.0             58.0           5.38
# 19             95.0             44.0           9.34
# 20             91.0             57.0          11.31
# 21             94.0             62.0           9.18
# 22             97.0             60.0           5.32
# 23             94.0             53.0           4.11
# 24             97.0             55.0            2.9
# 25             96.0             35.0           5.16
# 26             90.0             52.0           5.77
# 27             92.0             48.0           6.36
# 28             94.0             48.0           4.91
# 29             96.0             55.0           3.83
# 30             93.0             57.0           4.29
# 31             95.0             56.0           3.61
# 32             97.0             42.0           3.21
# 33             95.0             16.0           4.72
# 34             85.0             57.0           9.41
# 35             95.0             51.0           4.69
# 36             95.0             38.0           6.01
# 37             85.0             44.0           7.84
# 38             83.0             44.0           5.45
# 39             94.0             38.0           2.94
# 40             95.0             28.0           5.07
# 41             97.0             60.0           9.52
# 42             92.0             43.0           8.81
# 43             94.0             48.0           8.79
# 44             83.0             49.0            8.2
# 45             87.0             46.0           5.79
# 46             95.0             57.0           5.73
# 47             78.0             48.0           8.29
# 48             85.0             31.0           6.02
# 49             82.0             38.0           6.11

# %% [markdown]
# ### V2 regular cleaning -  EDA(Exploratory data analysis) - duplicated

# %%
# Load data
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'E:\study\meteoroData_clean\all_states_weather_v2.csv')

# 1. Detect duplicate rows
duplicate_rows = df[df.duplicated(keep=False)]
dup_count = df.duplicated().sum()
print(f"Number of duplicate rows: {dup_count}")

# Identify which rows are duplicates (both original and their duplicates)
dup_rows = df[df.duplicated(keep=False)]
dup_rows.head()
# Out:
# Number of duplicate rows: 16
#              date state       station max_Temperature_C min_Temperature_C  \
# 49251  2023-08-30   VIC  MOUNT HOTHAM               3.0               1.0
# 49252  2023-08-31   VIC  MOUNT HOTHAM               3.6              -2.5
# 49253  2023-08-30   VIC  MOUNT HOTHAM               3.0               1.0
# 49254  2023-08-31   VIC  MOUNT HOTHAM               3.6              -2.5
# 49316  2023-12-27   VIC  MOUNT HOTHAM              13.4               6.8
#
#       max_Humidity_pct min_Humidity_pct wind_speed_m_s
# 49251            100.0             74.0            9.8
# 49252            100.0             84.0            4.6
# 49253            100.0             74.0            9.8
# 49254            100.0             84.0            4.6
# 49316            100.0             70.0           3.38

# %%
# delete duplicated row
clean_df = df.drop_duplicates()
print(f"Number of duplicate rows: {dup_count} have been drop")

clean_df.to_csv(v2_path, index=False, encoding="utf-8")
print(f"Written cleaned data to: {v2_path}")
# Out:
# Number of duplicate rows: 16 have been drop
# Written cleaned data to: E:\study\meteoroData_clean\all_states_weather_v2.csv

# %% [markdown]
# ### finished preprocessing double check everything

# %%
file_path = r"E:\study\meteoroData_clean\all_states_weather_v2.csv"
df = pd.read_csv(file_path, encoding="utf-8")

# %%
rows, cols = df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {cols}")
# Out:
# Number of rows: 310695
# Number of columns: 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310695 entries, 0 to 310694
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date               310695 non-null  object
#  1   state              310695 non-null  object
#  2   station            310695 non-null  object
#  3   max_Temperature_C  303160 non-null  float64
#  4   min_Temperature_C  305258 non-null  float64
#  5   max_Humidity_pct   309279 non-null  float64
#  6   min_Humidity_pct   309279 non-null  float64
#  7   wind_speed_m_s     309279 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 19.0+ MB

# %%
df['date'] = pd.to_datetime(df['date'])
numeric_cols = [
    'max_Temperature_C',
    'min_Temperature_C',
    'max_Humidity_pct',
    'min_Humidity_pct',
    'wind_speed_m_s'
]
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
# Cell 4: （可选）将分类列转换为 category 类型，加快后续分组/筛选
df['state']   = df['state'].astype('category')
df['station'] = df['station'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310695 entries, 0 to 310694
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date               310695 non-null  datetime64[ns]
#  1   state              310695 non-null  category
#  2   station            310695 non-null  category
#  3   max_Temperature_C  303160 non-null  float64
#  4   min_Temperature_C  305258 non-null  float64
#  5   max_Humidity_pct   309279 non-null  float64
#  6   min_Humidity_pct   309279 non-null  float64
#  7   wind_speed_m_s     309279 non-null  float64
# dtypes: category(2), datetime64[ns](1), float64(5)
# memory usage: 15.1 MB

# %%
v2_path = r"E:\study\meteoroData_clean\all_states_weather_v2.csv"
df.to_csv(v2_path, index=False, encoding="utf-8")
print(f"Written cleaned data to: {v2_path}")
df.info()
# Out:
# Written cleaned data to: E:\study\meteoroData_clean\all_states_weather_v2.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310695 entries, 0 to 310694
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date               310695 non-null  datetime64[ns]
#  1   state              310695 non-null  category
#  2   station            310695 non-null  category
#  3   max_Temperature_C  303160 non-null  float64
#  4   min_Temperature_C  305258 non-null  float64
#  5   max_Humidity_pct   309279 non-null  float64
#  6   min_Humidity_pct   309279 non-null  float64
#  7   wind_speed_m_s     309279 non-null  float64
# dtypes: category(2), datetime64[ns](1), float64(5)
# memory usage: 15.1 MB

# %% [markdown]
# ## Data Analysis

# %%
#null value
missing = df.isnull().sum()
print(missing)
# Out:
# date                    0
# state                   0
# station                 0
# max_Temperature_C    7535
# min_Temperature_C    5437
# max_Humidity_pct     1416
# min_Humidity_pct     1416
# wind_speed_m_s       1416
# year_month              0
# dtype: int64

# %%
file_path = r"E:\study\meteoroData_clean\all_states_weather_v2.csv"
df = pd.read_csv(file_path, encoding="utf-8")
df['date'] = pd.to_datetime(df['date'])
df['year_month'] = df['date'].dt.to_period('M')
to_fill = ['max_Temperature_C', 'min_Temperature_C', 'wind_speed_m_s']
for col in to_fill:
    monthly_avg = df.groupby('year_month')[col].transform('mean')
    df[col] = df[col].fillna(monthly_avg)
print(df[to_fill].isnull().sum())
# Out:
# max_Temperature_C    0
# min_Temperature_C    0
# wind_speed_m_s       0
# dtype: int64

# %%
v3_path = r"E:\study\meteoroData_clean\all_states_weather_v3.csv"
df.to_csv(v3_path, index=False, encoding="utf-8")
print(f"Written cleaned data to: {v3_path}")
# Out:
# Written cleaned data to: E:\study\meteoroData_clean\all_states_weather_v3.csv

# %%
summary = df.groupby('station')['date'].agg(['min','max','nunique'])
summary['span_days'] = (summary['max'] - summary['min']).dt.days
print(summary.sort_values('span_days').head(10))
# Out:
#                                                  min        max  nunique  \
# station
# INGHAM AERO                               2024-02-01 2024-02-20       20
# SHEOAKS                                   2022-05-01 2022-08-06       98
# PORTLAND (CASHMORE AIRPORT)               2022-05-01 2023-05-06      371
# PORT MAQUARIE (PORT MACQUARIE AIRPORT AW) 2022-05-01 2023-06-04      397
# PORT MACQUARIE AIRPORT                    2023-06-01 2025-04-30      700
# PORTLAND AIRPORT                          2023-05-01 2025-04-30      731
# GUNNEDAH RESOURCE CENTRE                  2022-12-01 2025-04-30      882
# SHE OAKS                                  2022-08-01 2025-04-30     1004
# LISMORE AIRPORT                           2022-07-01 2025-04-30     1034
# AIREYS INLET                              2022-05-01 2025-04-30     1094
#
#                                            span_days
# station
# INGHAM AERO                                       19
# SHEOAKS                                           97
# PORTLAND (CASHMORE AIRPORT)                      370
# PORT MAQUARIE (PORT MACQUARIE AIRPORT AW)        399
# PORT MACQUARIE AIRPORT                           699
# PORTLAND AIRPORT                                 730
# GUNNEDAH RESOURCE CENTRE                         881
# SHE OAKS                                        1003
# LISMORE AIRPORT                                 1034
# AIREYS INLET                                    1095

# %%
summary = df.groupby('station')['date'].agg(['min','max','nunique'])
summary['span_days'] = (summary['max'] - summary['min']).dt.days
top10    = summary.nlargest(10, 'span_days')
bottom10 = summary.nsmallest(10, 'span_days')


fig, ax = plt.subplots(figsize=(10, 6))
top10['span_days'].plot(
    kind='bar', ax=ax
)
ax.set_title('Top 10 Stations by Coverage Span (days)')
ax.set_xlabel('Station')
ax.set_ylabel('Span (days)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
bottom10['span_days'].plot(
    kind='bar', ax=ax, color='orange'
)
ax.set_title('Bottom 10 Stations by Coverage Span (days)')
ax.set_xlabel('Station')
ax.set_ylabel('Span (days)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
bad = df[
    (df.min_Temperature_C < -20) | (df.min_Temperature_C > 60) |
    (df.max_Temperature_C < -20) | (df.max_Temperature_C > 60) | 
    (df.max_Humidity_pct < 0) | (df.max_Humidity_pct > 100) |
    (df.min_Humidity_pct < 0) | (df.min_Humidity_pct > 100) |
    (df.wind_speed_m_s < 0)
]
print("number of bad data:", len(bad))
# Out:
# number of bad data: 0

# %%
# 
df = pd.read_csv('E:/study/meteoroData_clean/all_states_weather_v3.csv', parse_dates=['date'])
# Cell 3: 中心趋势：整体 & 按州分组
key_vars = ['max_Temperature_C', 'min_Temperature_C', 'max_Humidity_pct', 'min_Humidity_pct', 'wind_speed_m_s']

# 整体均值、中位数
desc_all = df[key_vars].agg(['mean','median']).T
print("Overall mean & median:\n", desc_all)

# 按 state 分组的均值
desc_by_state = df.groupby('state')[key_vars].agg(['mean','median'])
print("\nBy-state mean & median:\n", desc_by_state)
# Out:
# Overall mean & median:
#                          mean     median
# max_Temperature_C  24.259339  24.500000
# min_Temperature_C  12.834982  12.866308
# max_Humidity_pct   89.725099  95.000000
# min_Humidity_pct   47.472851  48.000000
# wind_speed_m_s      3.561740   3.240000
#
# By-state mean & median:
#        max_Temperature_C        min_Temperature_C        max_Humidity_pct  \
#                    mean median              mean median             mean
# state
# NSW           23.142834   22.8         11.106531   11.4        89.994918
# QLD           28.932174   29.1         17.531007   18.6        87.175337
# VIC           19.671586   18.7          9.066675    9.1        92.696632
#
#              min_Humidity_pct        wind_speed_m_s
#       median             mean median           mean median
# state
# NSW     95.0        45.869585   46.0       3.396404   3.11
# QLD     93.0        46.081225   47.0       3.424249   3.16
# VIC     96.0        51.527232   53.0       3.971980   3.57

# %%
var_all = df[key_vars].agg(['std', lambda x: x.quantile(0.75)-x.quantile(0.25)]).T
var_all.rename(columns={'<lambda_0>':'IQR'}, inplace=True)
print("Overall variability:\n", var_all)

# 按月
df['month'] = df['date'].dt.month
var_by_month = df.groupby('month')[key_vars].agg(['mean','std'])
print("\nMonthly mean & std:\n", var_by_month)
# Out:
# Overall variability:
#                           std  <lambda>
# max_Temperature_C   7.544637     11.00
# min_Temperature_C   7.016153     10.60
# max_Humidity_pct   13.529633     12.00
# min_Humidity_pct   19.342599     28.00
# wind_speed_m_s      2.018314      2.34
#
# Monthly mean & std:
#        max_Temperature_C           min_Temperature_C            \
#                    mean       std              mean       std
# month
# 1             29.935176  5.835657         18.473691  5.053894
# 2             29.730025  5.494770         17.991257  5.209446
# 3             28.318409  5.601411         17.269738  5.264219
# 4             24.279761  5.529440         13.315123  5.574077
# 5             20.417260  5.787582          9.837735  6.247998
# 6             17.975166  6.406187          7.350598  5.755352
# 7             17.455600  5.912538          6.886546  5.711197
# 8             20.182811  6.337920          8.361602  5.533582
# 9             22.541066  6.759344         10.055180  5.964763
# 10            24.774723  6.912940         12.694290  6.049763
# 11            26.812789  6.657373         15.164974  5.979747
# 12            28.953760  6.455093         16.856750  5.804634
#
#       max_Humidity_pct            min_Humidity_pct            wind_speed_m_s  \
#                   mean        std             mean        std           mean
# month
# 1            88.510359  14.722372        45.920441  19.813871       3.756515
# 2            88.040556  14.275212        44.734121  19.604552       3.715831
# 3            89.465424  13.432009        47.804162  20.001203       3.474920
# 4            91.010847  11.406591        49.066143  17.123229       3.212332
# 5            92.007420  10.961163        53.061068  17.715680       3.210515
# 6            92.009607  10.469142        53.138121  17.930999       3.258116
# 7            92.343463  10.069243        53.554438  18.516896       3.469118
# 8            91.069606  12.565066        48.838569  18.611852       3.365183
# 9            88.227114  15.550064        43.025724  19.011426       3.707328
# 10           87.945314  15.733302        43.418753  19.732625       3.900331
# 11           88.301799  14.754550        44.218669  19.278069       3.827577
# 12           87.648055  15.301476        42.652461  19.661926       3.848749
#
#
#             std
# month
# 1      1.850799
# 2      1.915889
# 3      1.970077
# 4      1.906368
# 5      2.049773
# 6      2.089024
# 7      2.176642
# 8      2.108171
# 9      2.105920
# 10     2.018369
# 11     1.891683
# 12     1.914779
